# %% [markdown]
# # Dimensionality reduction

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("notebook", font_scale=1.4)
sns.set_style("whitegrid")
from IPython.core.display import HTML
css_file = '../../my.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Open+Sans' rel='stylesheet' type='text/css'>
#
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
#
# #notebook_panel { /* main background */
#     background: #888;
#     color: #f6f6f6;
# }
#
# div.cell { /* set cell width to about 80 chars */
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     margin: auto;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 3px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     /*background-color: rgba(171,165,131,0.3); /*
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     /*margin-top: 1em;*/
# }
#
# div.text_cell_render{
#     font-family: 'Open Sans', Helvetica;
#     line-height: 140%;
#     font-size: 105%;
#     /*margin-top:15px;*/
#     margin-bottom:8px;
#     text-align:justify;
# }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Open Sans',sans-serif;
#     font-weight: 100;
#     font-size: 30pt;
#     line-height: 100%;
#     display: block;
# }
#
# .text_cell_render h2 {
#     font-family: 'Philosopher', serif;
#     font-weight: 700;
#     font-size: 24pt;
#     line-height: 100%;
#     color: rgb(171,165,131);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Philosopher', serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(95,92,72);
# }
#
# .text_cell_render h4 {
#     font-family: 'Philosopher', serif;
# }
#
# .text_cell_render h5 {
#     font-family: 'Alegreya Sans', sans-serif;
#     font-weight: 300;
#     font-size: 16pt;
#     color: grey;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 100%;
# }
#
# .output_area {
# 	margin-top:20px;
# }
#
# .output_stderr {
# 	display:none;
# 	}
#
# .output_subarea {
# 	display: block;
#     margin: 0 auto;
# }
#
# .output_png img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# .prompt {
# 	visible: false;
# 	}
#
# </style>

# %% [markdown]
# Load the smartphone data from the previous pratical session (3. Clustering). Prepare the data for analysis. Put the normalized features and the columns 'subject' and 'activity' in a pandas dataframe called `data`.

# %%
# solution !!
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('../04._Clustering/samsungData.csv')

activity = data.pop('activity')
subject = data.pop('subject')

data = pd.DataFrame(StandardScaler().fit_transform(data),columns=data.columns.values)
data = data.clip(-3,3)
data['subject'] = subject
data['activity'] = activity

# %% [markdown]
# How many data points were there for each person (hopefully you did not normalize the 'subject' column also)?

# %%
# solution !!
data['subject'].value_counts()
# Out:
# 25    409
# 21    408
# 26    392
# 30    383
# 28    382
# 27    376
# 23    372
# 17    368
# 16    366
# 19    360
# 1     347
# 29    344
# 3     341
# 15    328
# 6     325
# 14    323
# 22    321
# 11    316
# 7     308
# 5     302
# 8     281
# Name: subject, dtype: int64

# %% [markdown]
# Now we split the data set into a train and a test set. However, we will not do this *at random*. The column 'subject' is actually very important in this data set. If we want to create a tool that can recognize the activity of a person from the smartphone measurements then the unseen external data wel not be just a data point in the data set. It will be a data point **from a different person**. So the unseen external data should be different person, not just different data points.
#
# Create a variable `data_train` that contains all person with 'subject' number greater or equal to 20. Also create a variable `data_test` that contains all person with 'subject' number less than 20. Remove the column 'subject' from `data_train` and `data_test`.

# %%
# solution !!
data_train = data[data['subject'] >= 20]
data_test = data[data['subject'] < 20]

tmp = data_train.pop('subject')
tmp = data_test.pop('subject')

# %% [markdown]
# How many data points are there for each activity in the train set?

# %%
# solution !!
data_train['activity'].value_counts()
# Out:
# laying      676
# standing    651
# sitting     622
# walk        519
# walkup      476
# walkdown    443
# Name: activity, dtype: int64

# %% [markdown]
# Now we will make two classes from these six activities. Class "1" contains all data points annotated as 'walk', 'walkup' or 'walkdown'. The other data points belong to class "0". Creat a list `target2` from `target` such that each value 'walk', 'walkup' or 'walkdown' in `target` is replaced by 1 and all other values by 0.

# %%
# solution!!
target_train = [1 if ((x=='walkup')) else 0 for x in data_train['activity']]
target_test = [1 if ((x=='walkup')) else 0 for x in data_test['activity']]

tmp = data_train.pop('activity')
tmp = data_test.pop('activity')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_score

model = LogisticRegression()
print np.mean(cross_val_score(model,data_train,target_train,cv=5,scoring='f1'))
# Out:
# 0.85317969606

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=20)
pca.fit(data_train)
data_pca_train = pd.DataFrame(pca.transform(data_train))
data_pca_test = pd.DataFrame(pca.transform(data_test))

# %%
print np.mean(cross_val_score(model,data_pca_train,target_train,cv=5,scoring='f1'))
# Out:
# 0.884655230852

# %%
from sklearn import metrics

model.fit(data_pca_train,target_train)
predictions = model.predict(data_pca_test)
print metrics.f1_score(target_test,predictions)
# Out:
# 0.835128417564

# %%
model.fit(data_train,target_train)
predictions = model.predict(data_test)
print metrics.f1_score(target_test,predictions)
# Out:
# 0.861417322835

# %%
data = pd.read_csv('../plants.csv')

# %%
data.shape
# Out:
# (34781, 71)

# %%
plants = data.pop('plant')

# %%
data.boxplot()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
data = pd.DataFrame(StandardScaler().fit_transform(data),columns=data.columns.values)

# %%
data.boxplot()
plt.show()

# %%
from sklearn.decomposition import PCA
import seaborn as sns

pca = PCA(n_components=2)
dataset_big_projected = pd.DataFrame(pca.fit(data).transform(data),columns=['PC1','PC2'])
#dataset_big_projected['label'] = targets

sns.lmplot(x="PC1", y="PC2", data=dataset_big_projected, 
           fit_reg=False, size=5.5, scatter_kws={"s": 80})
plt.show()

# %%
g = sns.jointplot(dataset_big_projected['PC1'],dataset_big_projected['PC2'], kind="kde", size=8, space=0)

# %%
g = sns.jointplot(dataset_big_projected['PC1'],dataset_big_projected['PC2'], kind="hex", size=8, space=0)

# %%
data = pd.read_csv('../plants.csv')

# %%
data = data.T

# %%
data.columns.values
# Out:
# array([    0,     1,     2, ..., 34778, 34779, 34780])

# %%
data.iloc[0,:]
# Out:
# 0                                       abelia
# 1                         abelia x grandiflora
# 2                                  abelmoschus
# 3                       abelmoschus esculentus
# 4                        abelmoschus moschatus
# 5                                        abies
# 6                                   abies alba
# 7                               abies amabilis
# 8                               abies balsamea
# 9                 abies balsamea var. balsamea
# 10            abies balsamea var. phanerolepis
# 11                             abies bracteata
# 12                              abies concolor
# 13                abies concolor var. concolor
# 14                 abies concolor var. lowiana
# 15                               abies fraseri
# 16                               abies grandis
# 17                             abies homolepis
# 18                            abies lasiocarpa
# 19             abies lasiocarpa var. arizonica
# 20            abies lasiocarpa var. lasiocarpa
# 21                             abies magnifica
# 22                               abies procera
# 23                           abies �shastensis
# 24                                abildgaardia
# 25                          abildgaardia ovata
# 26                                     abronia
# 27                              abronia alpina
# 28                             abronia ameliae
# 29                           abronia ammophila
#                          ...
# 34751                     ziziphus obtusifolia
# 34752      ziziphus obtusifolia var. canescens
# 34753    ziziphus obtusifolia var. obtusifolia
# 34754                          ziziphus parryi
# 34755                      ziziphus reticulata
# 34756                        ziziphus rignonii
# 34757                        ziziphus taylorii
# 34758                        ziziphus zizyphus
# 34759                                   zornia
# 34760                         zornia bracteata
# 34761                           zornia gemella
# 34762                       zornia leptophylla
# 34763                        zornia reticulata
# 34764                                  zostera
# 34765                           zostera marina
# 34766                                   zoysia
# 34767                          zoysia japonica
# 34768                          zoysia matrella
# 34769            zoysia matrella var. matrella
# 34770            zoysia matrella var. pacifica
# 34771                        zoysia tenuifolia
# 34772                                   zuckia
# 34773                        zuckia brandegeei
# 34774         zuckia brandegeei var. arizonica
# 34775        zuckia brandegeei var. brandegeei
# 34776          zuckia brandegeei var. plummeri
# 34777                              zygophlebia
# 34778                   zygophlebia sectifrons
# 34779                              zygophyllum
# 34780                       zygophyllum fabago
# Name: plant, dtype: object

# %%
data.columns = data.iloc[0,:]

# %%
data.head()
# Out:
# plant  abelia  abelia x grandiflora  abelmoschus  abelmoschus esculentus  \
# plant  abelia  abelia x grandiflora  abelmoschus  abelmoschus esculentus
# va          0                     0            1                       1
# ab          0                     0            0                       0
# co          0                     0            0                       0
# dengl       0                     0            0                       0
#
# plant  abelmoschus moschatus  abies  abies alba  abies amabilis  \
# plant  abelmoschus moschatus  abies  abies alba  abies amabilis
# va                         0      1           0               0
# ab                         0      1           0               0
# co                         0      1           0               0
# dengl                      0      0           0               0
#
# plant  abies balsamea  abies balsamea var. balsamea         ...          \
# plant  abies balsamea  abies balsamea var. balsamea         ...
# va                  1                             1         ...
# ab                  1                             1         ...
# co                  0                             0         ...
# dengl               0                             0         ...
#
# plant  zoysia tenuifolia  zuckia  zuckia brandegeei  \
# plant  zoysia tenuifolia  zuckia  zuckia brandegeei
# va                     0       0                  0
# ab                     0       0                  0
# co                     0       1                  1
# dengl                  0       0                  0
#
# plant  zuckia brandegeei var. arizonica  zuckia brandegeei var. brandegeei  \
# plant  zuckia brandegeei var. arizonica  zuckia brandegeei var. brandegeei
# va                                    0                                  0
# ab                                    0                                  0
# co                                    0                                  1
# dengl                                 0                                  0
#
# plant  zuckia brandegeei var. plummeri  zygophlebia  zygophlebia sectifrons  \
# plant  zuckia brandegeei var. plummeri  zygophlebia  zygophlebia sectifrons
# va                                   0            0                       0
# ab                                   0            0                       0
# co                                   1            0                       0
# dengl                                0            0                       0
#
# plant  zygophyllum  zygophyllum fabago
# plant  zygophyllum  zygophyllum fabago
# va               0                   0
# ab               0                   0
# co               1                   1
# dengl            0                   0
#
# [5 rows x 34781 columns]

# %%
data = data.iloc[1:,:]

# %%
data.head()
# Out:
# plant abelia abelia x grandiflora abelmoschus abelmoschus esculentus  \
# va         0                    0           1                      1
# ab         0                    0           0                      0
# co         0                    0           0                      0
# dengl      0                    0           0                      0
# vi         0                    0           1                      1
#
# plant abelmoschus moschatus abies abies alba abies amabilis abies balsamea  \
# va                        0     1          0              0              1
# ab                        0     1          0              0              1
# co                        0     1          0              0              0
# dengl                     0     0          0              0              0
# vi                        0     0          0              0              0
#
# plant abies balsamea var. balsamea        ...         zoysia tenuifolia  \
# va                               1        ...                         0
# ab                               1        ...                         0
# co                               0        ...                         0
# dengl                            0        ...                         0
# vi                               0        ...                         0
#
# plant zuckia zuckia brandegeei zuckia brandegeei var. arizonica  \
# va         0                 0                                0
# ab         0                 0                                0
# co         1                 1                                0
# dengl      0                 0                                0
# vi         0                 0                                0
#
# plant zuckia brandegeei var. brandegeei zuckia brandegeei var. plummeri  \
# va                                    0                               0
# ab                                    0                               0
# co                                    1                               1
# dengl                                 0                               0
# vi                                    0                               0
#
# plant zygophlebia zygophlebia sectifrons zygophyllum zygophyllum fabago
# va              0                      0           0                  0
# ab              0                      0           0                  0
# co              0                      0           1                  1
# dengl           0                      0           0                  0
# vi              0                      0           0                  0
#
# [5 rows x 34781 columns]

# %%
data_states = data.index

# %%
data_states
# Out:
# Index([u'va', u'ab', u'co', u'dengl', u'vi', u'ak', u'al', u'ar', u'vt', u'il',
#        u'ga', u'in', u'ia', u'az', u'id', u'ct', u'pr', u'ks', u'nj', u'mb',
#        u'lb', u'nm', u'tx', u'la', u'nb', u'nc', u'nd', u'ne', u'nf', u'tn',
#        u'ny', u'pa', u'pe', u'ns', u'nt', u'ca', u'nv', u'nh', u'wa', u'bc',
#        u'de', u'dc', u'wi', u'wv', u'hi', u'fraspm', u'ok', u'on', u'fl',
#        u'yt', u'wy', u'gl', u'me', u'md', u'ma', u'oh', u'ut', u'mo', u'mn',
#        u'mi', u'ri', u'sk', u'mt', u'qc', u'ms', u'sc', u'ky', u'nu', u'or',
#        u'sd'],
#       dtype='object')

# %%
from sklearn.decomposition import PCA
import seaborn as sns

pca = PCA(n_components=2)
dataset_big_projected = pd.DataFrame(pca.fit(data).transform(data),columns=['PC1','PC2'])
#dataset_big_projected['label'] = targets

sns.lmplot(x="PC1", y="PC2", data=dataset_big_projected, 
           fit_reg=False, size=5.5, scatter_kws={"s": 80})
plt.show()

# %%
sns.lmplot(x="PC1", y="PC2", data=dataset_big_projected, 
           fit_reg=False, size=12.5, scatter_kws={"s": 80})
for i, (x, y) in enumerate(zip(dataset_big_projected['PC1'], dataset_big_projected['PC2'])):
    plt.annotate(
        data_states[i], 
        xy = (x, y), xytext = (-20, 20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'white', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))	
plt.show()

# %%
cg = sns.clustermap(data,method="single",figsize=(14,50))
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-a07b3c966458> in <module>()
# ----> 1 cg = sns.clustermap(data,method="single",figsize=(14,50))
#       2 plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
#       3 plt.show()
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/seaborn/matrix.pyc in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, **kwargs)
#    1167                         row_cluster=row_cluster, col_cluster=col_cluster,
#    1168                         row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1169                         **kwargs)
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/seaborn/matrix.pyc in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, **kws)
#    1006         colorbar_kws = {} if colorbar_kws is None else colorbar_kws
#    1007         self.plot_dendrograms(row_cluster, col_cluster, metric, method,
# -> 1008                               row_linkage=row_linkage, col_linkage=col_linkage)
#    1009         try:
#    1010             xind = self.dendrogram_col.reordered_ind
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/seaborn/matrix.pyc in plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage)
#     939             self.dendrogram_col = dendrogram(
#     940                 self.data2d, metric=metric, method=method, label=False,
# --> 941                 axis=1, ax=self.ax_col_dendrogram, linkage=col_linkage)
#     942         else:
#     943             self.ax_col_dendrogram.set_xticks([])
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/seaborn/matrix.pyc in dendrogram(data, linkage, axis, label, metric, method, rotate, ax)
#     682     plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     683                                  metric=metric, method=method,
# --> 684                                  label=label, rotate=rotate)
#     685     if ax is None:
#     686         ax = plt.gca()
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/seaborn/matrix.pyc in __init__(self, data, linkage, metric, method, axis, label, rotate)
#     500         else:
#     501             self.linkage = linkage
# --> 502         self.dendrogram = self.calculate_dendrogram()
#     503
#     504         # Dendrogram ends are always at multiples of 5, who knows why
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/seaborn/matrix.pyc in calculate_dendrogram(self)
#     580         """
#     581         return hierarchy.dendrogram(self.linkage, no_plot=True,
# --> 582                                     color_threshold=-np.inf)
#     583
#     584     @property
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    2292         contraction_marks=contraction_marks,
#    2293         link_color_func=link_color_func,
# -> 2294         above_threshold_color=above_threshold_color)
#    2295
#    2296     if not no_plot:
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in _dendrogram_calculate_info(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, i, iv, ivl, n, icoord_list, dcoord_list, lvs, mhr, current_color, color_list, currently_below_threshold, leaf_label_func, level, contraction_marks, link_color_func, above_threshold_color)
#    2580             level=level + 1, contraction_marks=contraction_marks,
#    2581             link_color_func=link_color_func,
# -> 2582             above_threshold_color=above_threshold_color)
#    2583
#    2584     max_dist = max(uamd, ubmd, h)
#
# ... last 1 frames repeated, from the frame below ...
#
# /home/pitro11a/anaconda2/envs/I3/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in _dendrogram_calculate_info(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, i, iv, ivl, n, icoord_list, dcoord_list, lvs, mhr, current_color, color_list, currently_below_threshold, leaf_label_func, level, contraction_marks, link_color_func, above_threshold_color)
#    2580             level=level + 1, contraction_marks=contraction_marks,
#    2581             link_color_func=link_color_func,
# -> 2582             above_threshold_color=above_threshold_color)
#    2583
#    2584     max_dist = max(uamd, ubmd, h)
#
# RuntimeError: maximum recursion depth exceeded while calling a Python object
