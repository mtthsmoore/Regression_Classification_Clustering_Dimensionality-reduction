# %% [markdown]
# # Clustering

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("notebook", font_scale=1.4)
sns.set_style("whitegrid")
from IPython.core.display import HTML
css_file = '../../my.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Open+Sans' rel='stylesheet' type='text/css'>
#
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
#
# #notebook_panel { /* main background */
#     background: #888;
#     color: #f6f6f6;
# }
#
# div.cell { /* set cell width to about 80 chars */
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     margin: auto;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 3px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     /*background-color: rgba(171,165,131,0.3); /*
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     /*margin-top: 1em;*/
# }
#
# div.text_cell_render{
#     font-family: 'Open Sans', Helvetica;
#     line-height: 140%;
#     font-size: 105%;
#     /*margin-top:15px;*/
#     margin-bottom:8px;
#     text-align:justify;
# }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Open Sans',sans-serif;
#     font-weight: 100;
#     font-size: 30pt;
#     line-height: 100%;
#     display: block;
# }
#
# .text_cell_render h2 {
#     font-family: 'Philosopher', serif;
#     font-weight: 700;
#     font-size: 24pt;
#     line-height: 100%;
#     color: rgb(171,165,131);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Philosopher', serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(95,92,72);
# }
#
# .text_cell_render h4 {
#     font-family: 'Philosopher', serif;
# }
#
# .text_cell_render h5 {
#     font-family: 'Alegreya Sans', sans-serif;
#     font-weight: 300;
#     font-size: 16pt;
#     color: grey;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 100%;
# }
#
# .output_area {
# 	margin-top:20px;
# }
#
# .output_stderr {
# 	display:none;
# 	}
#
# .output_subarea {
# 	display: block;
#     margin: 0 auto;
# }
#
# .output_png img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
#
# .prompt {
# 	visible: false;
# 	}
#
# </style>

# %% [markdown]
# In 2013 a data set was published<sup>1</sup> about human activity recognition using smartphones. For a group of 30 volunteers within an age bracket of 19-48 years each person performed six activities (WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, SITTING, STANDING, LAYING) wearing a smartphone (Samsung Galaxy S II) on the waist. Using its embedded accelerometer and gyroscope, 3-axial linear acceleration and 3-axial angular velocity were captured at a constant rate of 50Hz. The experiments have been video-recorded to label the data manually. The sensor signals (accelerometer and gyroscope) were pre-processed by applying noise filters and then sampled in fixed-width sliding windows of 2.56 sec and 50% overlap (128 readings/window). From each window, a vector of features was obtained by calculating variables from the time and frequency domain. You can watch this small video to learn more about how the data was collected:
#
#
# [![video](http://img.youtube.com/vi/XOEN9W05_4A/0.jpg)](http://www.youtube.com/watch?v=XOEN9W05_4A "Collecting Data")
#
#
# > [1] D. Anguita, A. Ghio, L. Oneto, X. Parra and J. L. Reyes-Ortiz. *A Public Domain Dataset for Human Activity Recognition Using Smartphones*. 21th European Symposium on Artificial Neural Networks, Computational Intelligence and Machine Learning, ESANN 2013. Bruges, Belgium 24-26 April 2013.
#
# Lets load the data set, the file is called "samsungData.csv".

# %%
data = pd.read_csv('samsungData.csv')

# %% [markdown]
# The data set contains the features and two additional columns: 'subject' and 'activity'. The 'subject' is the anonymous identifier of the person from which the measurements were recorded. The 'activity' column contains one of the six activities that were annotated. How many rows are there for each person? How many for each activity?

# %%
# solution !!
print data['subject'].value_counts()
print data['activity'].value_counts()
# Out:
# 25    409
# 21    408
# 26    392
# 30    383
# 28    382
# 27    376
# 23    372
# 17    368
# 16    366
# 19    360
# 1     347
# 29    344
# 3     341
# 15    328
# 6     325
# 14    323
# 22    321
# 11    316
# 7     308
# 5     302
# 8     281
# Name: subject, dtype: int64
# laying      1407
# standing    1374
# sitting     1286
# walk        1226
# walkup      1073
# walkdown     986
# Name: activity, dtype: int64

# %% [markdown]
# Person '25' has the most rows in the data set. Create a variable `data_25` that contains only the rows for person '25'.

# %%
# solution!!!
data_25 = data[data.subject==25]

# %% [markdown]
# Now remove column 'subject' form `data_25`.

# %%
# solution!!!
tmp = data_25.pop('subject')

# %% [markdown]
# Also remove the column 'activity' from `data_25` and store in a variable called `target`.

# %%
# solution!!!
target = data_25.pop('activity')

# %% [markdown]
# Now `data_25` only contains the features. Investigate the distribution and ranges of the first 100 features.

# %%
# solution !!
plt.figure(figsize=(12,15))
data_25.iloc[:,:100].boxplot(vert=False)
plt.show()

# %% [markdown]
# As you can see, some data sets are very hard to normalize. We see features with very different ranges and very different shapes of distributions. Start bt standardizing all the features.

# %%
# solution !!
from sklearn.preprocessing import StandardScaler
data_25 = pd.DataFrame(StandardScaler().fit_transform(data_25),columns=data_25.columns.values)

# %% [markdown]
# Again investigate the first 100 features.

# %%
# solution !!
plt.figure(figsize=(12,15))
data_25.iloc[:,:100].boxplot(vert=False,flierprops=dict(marker='o', markersize=5))
plt.show()

# %% [markdown]
# We have now somewhat centered the distributions of the features. However, many features ahve many outliers. We can look at these outliers better by providing the argument `flierprops=dict(marker='o', markersize=5)` to the `boxplot()` function of the pandas dataframe. Add this argument to the `boxplot()` function you should have used when investigating the first 100 features.

# %%
# solution !!
plt.figure(figsize=(12,15))
data_25.iloc[:,:100].boxplot(vert=False,flierprops=dict(marker='o', markersize=5))
plt.show()

# %% [markdown]
# To reduct the impact of these outlying values we can trim them to a certain range. This means that if a feature value is less or more than the trimming values it is replace by the closest trimming value. The pandas dataframe has a function called [`clip()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.clip.html) that will trim the features within a minimum and a maximum value. Trim the data set within [-3,3].

# %%
# solution !!
data_25 = data_25.clip(-3,3)

# %% [markdown]
# What do the feature distributions look like now?

# %%
# solution !!
plt.figure(figsize=(12,15))
data_25.iloc[:,:100].boxplot(vert=False,flierprops=dict(marker='o', markersize=5))
plt.show()

# %% [markdown]
# The data set is ready for K-means clustering. What would be a good value for the number of clusters $k$ that the K-means++ implementation of scikit-learn requires as hyperparameter? Use the 'silhouette coefficient' and 'inertia' metrics to evaluate different values for $k$. Plot the results.

# %%
# solution!!
from sklearn.cluster import KMeans
from sklearn import metrics

kmeans = KMeans(init='k-means++')

s_sil = []
s_in = []
for k in range(2,10):
    kmeans.n_clusters = k
    kmeans.fit(data_25)
    labels = kmeans.labels_
    s_sil.append(metrics.silhouette_score(data_25, labels))
    s_in.append(kmeans.inertia_)

cluster_evaluation = pd.DataFrame()
cluster_evaluation['k'] = range(2,10)
cluster_evaluation['silhouette'] = s_sil
cluster_evaluation['inertia'] = s_in
    
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.pointplot(x="k", y="silhouette", data=cluster_evaluation)
plt.subplot(1,2,2)
sns.pointplot(x="k", y="inertia", data=cluster_evaluation)
plt.show()

# %% [markdown]
# What would you conclude from these plots? Create scikit-learn K-means++ object called `kmeans` and fit a model with 6 clusters (this was the number of activities in the data set).

# %%
# solution!!
kmeans = KMeans(init='k-means++',n_clusters=6)
kmeans.fit(data_25)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=6, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %% [markdown]
# Pandas contains a function `crosstab()` that evaluates how well the clusters match the true grouping by activity. This can be done as follows:

# %%
ct = pd.crosstab(kmeans.labels_,target)
ct
# Out:
# activity  laying  sitting  standing  walk  walkdown  walkup
# row_0
# 0             42        7         6     0         0       0
# 1              0        0         0    71         2       0
# 2              0        0         0     3         7      65
# 3             16        0         0     0         0       0
# 4             15       58        68     0         0       0
# 5              0        0         0     0        49       0

# %% [markdown]
# What does this cross-table tell you about how well the data points are clustered for each activity?
#
# Now will perform hierarchical clustering on this normalized data set. First we create a python list `a_colors` that contains the target activities as colors. This list can be used for the `row_colors` argument of the seaborn `clustermap()` function.

# %%
activities2color = {}
activities2color['laying'] = 'purple'
activities2color['sitting'] = 'green'
activities2color['standing'] = 'blue'
activities2color['walk'] = 'yellow'
activities2color['walkdown'] = 'brown'
activities2color['walkup'] = 'red'

a_colors = [activities2color[x] for x in target]

# %% [markdown]
# Use `clustermap()` to create a row and column dendogram of the data as a heatmap using single-linkage. In the plot the rows need to be the data points. Use the `row_colors` argument to add the true activities to the plot.

# %%
# solution !!
cg = sns.clustermap(data_25,method="single",figsize=(14,50), row_colors=a_colors)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()
